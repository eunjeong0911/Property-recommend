# %%
import pandas as pd

df = pd.read_csv("C:/dev/study/eunjeong/SKN18-FINAL-1TEAM/data/raw/부동산중개업자정보.csv")
print(df.head())
# Out:
#    법정동코드       법정동명              등록번호        사업자상호 중개업자명  중개업자종별코드 중개업자종별명  \
# 0  11110  서울특별시 종로구     92200000-1523   양지공인중개사사무소   이인애         2   공인중개사
# 1  11110  서울특별시 종로구  11110-2021-00034   송정공인중개사사무소   황치영         4   중개보조원
# 2  11110  서울특별시 종로구  11110-2018-00044     이로운부동산중개   김영민         4   중개보조원
# 3  11110  서울특별시 종로구  11110-2019-00009   낙원공인중개사사무소   김진식         2   공인중개사
# 4  11110  서울특별시 종로구  11110-2020-00063  경희궁자이탑부동산중개   최은숙         2   공인중개사
#
#            자격증번호      자격증취득일  직위구분코드 직위구분명     데이터기준일자
# 0           1851  1999-06-14       1    대표  2025-12-04
# 1            NaN         NaN       4    일반  2025-12-04
# 2            NaN         NaN       4    일반  2025-12-04
# 3            301  1999-06-22       1    대표  2025-12-04
# 4  11-2021-02948  2021-12-13       4    일반  2025-12-04

# %%
import pandas as pd

df = pd.read_csv("C:/dev/study/eunjeong/SKN18-FINAL-1TEAM/data/raw/broker_office.csv")
print(df.head())
# Out:
#          jurirno brkrNm  ldCode   ldCodeNm    registDe sttusSeCodeNm  \
# 0   나92200000-51    강정식   11110  서울특별시 종로구  1984-06-01           영업중
# 1  92200000-2065    권오윤   11110  서울특별시 종로구  1984-06-01           영업중
# 2   나92200000-83    문행진   11110  서울특별시 종로구  1984-06-01           영업중
# 3   나92200000-93    김영일   11110  서울특별시 종로구  1984-06-01           영업중
# 4   나92200000-74    이희만   11110  서울특별시 종로구  1984-06-14           영업중
#
#                rdnmadrcode               mnnmadr             rdnmadr  \
# 0  11110310001300026600000  서울특별시 종로구 종로6가 262-1    서울특별시 종로구 종로 266
# 1  11110410035100001500000   서울특별시 종로구 창신동 580-3  서울특별시 종로구 종로51길 15
# 2  11110410045300002900000  서울특별시 종로구 창신동 651-43    서울특별시 종로구 창신길 29
# 3  11110410044500004200000  서울특별시 종로구 창신동 23-426  서울특별시 종로구 창신6가길 42
# 4  11110310000800001400000  서울특별시 종로구 명륜2가 147-3   서울특별시 종로구 성균관로 14
#
#   estbsBeginDe  lastUpdtDt  estbsEndDe  sttusSeCode     bsnmCmpnm 시군구명  시군구코드
# 0   2025-03-06  2025-11-24  2026-03-05            1  신흥사부동산중개인사무소  종로구  11110
# 1   2025-06-24  2025-11-24  2026-06-23            1   복지부동산중개인사무소  종로구  11110
# 2   2025-09-23  2025-11-24  2026-09-22            1   제일부동산중개인사무소  종로구  11110
# 3   2025-03-26  2025-11-24  2026-03-25            1  삼일사부동산중개인사무소  종로구  11110
# 4   2025-06-29  2025-11-24  2026-06-28            1   명륜부동산중개인사무소  종로구  11110

# %%
import pandas as pd

df = pd.read_csv("C:/dev/study/eunjeong/SKN18-FINAL-1TEAM/data/raw/match_02.csv")
print(df.head())
# Out:
#                등록번호           중개사명  \
# 0    11440202500004   동산이형공인중개사사무소
# 1  11620-2021-00225  새로부동산공인중개사사무소
# 2  11680-2023-00172    스카이공인중개사사무소
# 3  11680-2021-00138    더라움공인중개사사무소
# 4  11650-2022-00036     바른공인중개사사무소
#
#                                             주소   빌라  상가  아파트  오피스텔  원투룸  \
# 0      서울특별시 마포구 공덕동 467 롯데캐슬프레지던트 24층 오-2403호  217   1    0    31   99
# 1                 서울특별시 관악구 봉천동 947-15 1층 끝 상가   17   0    0     0   46
# 2  서울특별시 강남구 역삼동 825-20 강남역 센트럴 푸르지오 시티 2층218호   11   0    2    13   21
# 3            서울특별시 강남구 학동로8길 10 506호(논현동,은솔빌딩)   36  51   38    23   12
# 4           서울특별시 서초구 서초동 1630-2 와이에이치빌리지 102호    5   0    2     0    0
#
#      거래완료  등록매물  ...                mnnmadr               rdnmadr  \
# 0  404028   599  ...    서울특별시 마포구 공덕동 7-247    서울특별시 마포구 효창원로 242
# 1   17136   177  ...    서울특별시 관악구 봉천동 708-7      서울특별시 관악구 당곡길 52
# 2    7332    99  ...   서울특별시 강남구 역삼동 718-30  서울특별시 강남구 테헤란로34길 14
# 3    1280   521  ...                    NaN                   NaN
# 4     441    11  ...  서울특별시 서초구 서초동 1482-10   서울특별시 서초구 반포대로7길 32
#
#    estbsBeginDe  lastUpdtDt  estbsEndDe  sttusSeCode       bsnmCmpnm 시군구명  \
# 0    2025-06-30  2025-11-24  2026-06-29          1.0     우정부동산중개인사무소  종로구
# 1    2025-07-23  2025-11-24  2026-07-22          1.0      우정부동산중개사무소  종로구
# 2    2026-03-06  2025-11-24  2027-03-05          1.0  주식회사우대빵부동산중개센터  종로구
# 3           NaN         NaN         NaN          NaN             NaN  NaN
# 4    2025-10-14  2025-11-24  2026-10-13          1.0     행운부동산중개사사무소  종로구
#
#      시군구코드     rdn_road
# 0  11110.0     마포구 효창원로
# 1  11110.0      관악구 당곡길
# 2  11110.0  강남구 테헤란로34길
# 3      NaN          NaN
# 4  11110.0   서초구 반포대로7길
#
# [5 rows x 36 columns]
